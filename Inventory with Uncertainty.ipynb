# %% [markdown]
# ### DATA SCIENCE AND SUPPLY CHAINS ANALYTICS. A – Z WITH PYTHON

# %% [markdown]
# ### Sección 16: Inventory with Uncertainty (Inventario con incertidumbre):

# %% [markdown]
# ### Intro:
#
# Ahora hablaremos de la cadena de suministro y cómo modelar esta incertidumbre dentro de nuestra cadena de suministro. Como dijimos, tenemos muchas incertidumbres. Por ejemplo, el proveedor puede tardar demasiado en llegar.
#
# Las órdenes de los militares desde el momento en que él las ordena, pueden tardar demasiado en llegar. Entonces decimos en la orden de compra, por ejemplo, 20 días y el tipo tarda 30 días en llegar o por ejemplo, espero que venda 20 muestras de esta marca en mi tienda, pero de la nada, vinieron 30 clientes queriendo este espectáculo, por lo que esto es una incertidumbre.
#
# No estamos seguros de cuánto venderemos mañana. No estamos seguros de si nuestro proveedor llegará a tiempo o no y, por lo general, no llega a tiempo. Por lo general, llegan un poco tarde o un poco y muy rara vez el proveedor le dice 20 días y usted llega en 20 días.
#
# Debe haber algún tipo de variabilidad. Entonces, ¿cómo podemos modelar esta variabilidad y cómo podemos ponerla en nuestro inventario de seguridad? Si recuerdas nuestro ejemplo de distribución, el que tiene eso, dijimos que el promedio, por ejemplo, las ventas promedio eran 20, pero a veces en días malos que eran feriados o la gente estaba fuera del país o no.
#
# Muchas personas llegando a nuestra tienda. Vendemos 10 en temporada alta y cosas que podemos vender 30. Entonces, esto es mucha variabilidad y este es nuestro promedio, por lo que si mi proveedor tarda 20 días en llegar, por ejemplo, tarda 20 días en llegar y venden en promedio por día 20 artículos.
#
# ¿Cuánto de esto, cuántos artículos debo mantener en mi stock como mínimo? Creo que debería mantenerme alrededor de los 20. Los 20 artículos se multiplican por 20 y esto se llama usted ERM, usted reparte el promedio, el promedio que espero vender más tarde así que vendería 20 por día multiplicado por 20 días. Se espera que venda alrededor de 400 zapatos en esos 20 días, así que esto es mínimo.
#
# Pero como dijimos, también hay mucha incertidumbre, así que quizás debería mantener un poco más como reserva de seguridad y es un poco más.
#
# Cuanto extra? Bueno, está definido, pero por lo importante que es el producto para nosotros es extremadamente importante. Es un producto superestrella. Todos los clientes quieren comprar este producto.
#
# Es el que nos impulsa las ventas es el que nos impulsa. Este es un producto extremadamente importante, así que quiero estar en algún lugar aquí para cubrir el 95% de mi producto senior. Quiero cubrir toda esta ciudad. Uno, si es un subproducto. Ahora quiero cubrir solo esto cada uno.
#
# Y si es un producto de C, no me importa mucho, no genera ningún paso de todos modos, el margen de beneficio es cero. Es un producto CC, como hicimos para ABC, bajos ingresos, poca cantidad.
#
# Así que solo quiero tenerlo (No importa), definimos la portada en función de la importancia del producto para nosotros. Digamos que es un producto seguro y solo obtendrán esta cantidad. Lo que significa que solo obtendría un artículo o eso es todo, no más que esto, pero esta variabilidad solo por un día, estoy diciendo que un cliente, 21 clientes pueden venir al día siguiente 17, al día siguiente 16, pero tengo 20 días de más tarde.
#
# Entonces, ¿cómo puedo modelar durante los 20 días? Bueno, si estás atónito, la desviación estándar aquí es 1 día, solo que multiplicas por una raíz cuadrada de 20.
#
# Entonces, la raíz cuadrada de 20 le da la variabilidad en estos 20 días, no solo en 1 día, por lo que lo primero que hacemos es obtener la demanda promedio.
#
# Y luego lo multiplica por el tiempo de entrega para obtener más que la demanda promedio en el tiempo de entrega. La segunda cosa es que obtenemos la desviación estándar y usted multiplica la desviación estándar por la raíz cuadrada del tiempo de entrega y esto nos dará la desviación estándar en el tiempo de entrega de la demanda, por lo que aquí en nuestro caso, será 400.
#
# Dijimos que la desviación estándar es 1 multiplicado por disculpe, por la raíz cuadrada de 20 multiplica el nivel de servicio. Cuál es el nivel de servicio, lo que definimos aquí, por ejemplo, para el 95% será 1.64 y puede decir que nuestra cantidad mínima de pedido en cada momento será de alrededor de 418, por ejemplo.
#
# Entonces, en un momento dado, siempre que mi stock alcance los 418, tengo que volver a realizar un pedido a mi proveedor de inmediato. ¿Porqué es eso? Porque esos 418 son suficientes con algunas existencias de seguridad para satisfacer a mis clientes hasta que llegue mi proveedor con los espectáculos que necesito. Así que recuerde siempre esta regla aquí. El tiempo promedio demandado más Sigma.
#
# Multiplicado por el nivel de servicio o los factores clave que discutiremos luego de esto definiremos el máximo, el mínimo periódico, muchas de las políticas que discutiremos luego serán generalizadas por esta regla, promediar el tiempo más Sigma multiplicado por el nivel de servicio que necesitamos .
#
# Y como dije antes, cuanto más importante es el producto, mayor es la prestación del servicio, pero menos importante que el nivel de servicio.
#
# Lo menos importante que dices es que no quiero ningún servicio. No quiero ningún stock de seguridad. Simplemente estaré satisfecho con mi promedio basado en el análisis ABC de que tenemos precisamente eso.

# %% [markdown]
# ### Variability in Supply Chain (Variabilidad en la Cadena de Suministro):

# %% [markdown]
# **La cadena de suministro no es determinista todo el tiempo:**
#
# - Los pedidos pueden tardar más de lo esperado en llegar.
# - Pueden venir más clientes de los esperados.
# - Pueden venir menos clientes de los esperados.
# - Los clientes pueden pedir más volumen.
# - El programa de producción puede variar.
# - Es posible que los proveedores no tengan nuestro pedido ya en la mano.
#
# https://www.eazystock.com/blog/4-reasons-for-carrying-safety-stock-inventory/

# %%
import os
from IPython.display import Image
from IPython.display import YouTubeVideo

# %%
ruta = os.chdir("C:/ENRIQUE/PROGRAMACIÓN/PROYECTOS/Data Science and Supply Chain with Python/Seccion 16")

# %%
Image('Safety-Stock.png')

# %% [markdown]
# **Por qué necesitamos acciones de seguridad:**
#
# 1. Protéjase contra variaciones imprevistas en la oferta.
# 2. Compense las imprecisiones del pronóstico (solo cuando la demanda exceda el pronóstico).
# 3. Evitar interrupciones en la fabricación o entregas.
# 4. Evite la falta de existencias para mantener altos los niveles de satisfacción y servicio al cliente.

# %% [markdown]
# ### Demand Lead-Time and Sigma Demand Lead-Time (Plazo de entrega de demanda y Plazo de entrega de demanda Sigma):

# %%
Image('DL.png')

# %% [markdown]
# - Plazo de ejecución: 2 semanas
# - El pronóstico para 1 semana es 300.
# - ¿Cuál debería ser el stock mínimo?
# - Lo tendrías por este producto.
# - La cantidad de pedido es 500.

# %% [markdown]
# ### Preparing the data for safety stock calculations (Preparación de los datos para los cálculos de existencias de seguridad):

# %%
import pandas as pd
import inventorize3 as inv
import datetime
import numpy as np
import seaborn as sns

# %%
retail= pd.read_csv('online_retail2.csv')
retail.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
retail= retail.drop_duplicates()
retail= retail.dropna(axis=0)

# %%
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 797885 entries, 0 to 1067370
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      797885 non-null  object
#  1   StockCode    797885 non-null  object
#  2   Description  797885 non-null  object
#  3   Quantity     797885 non-null  int64
#  4   InvoiceDate  797885 non-null  object
#  5   Price        797885 non-null  float64
#  6   Customer ID  797885 non-null  float64
#  7   Country      797885 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 54.8+ MB

# %%
retail.InvoiceDate
retail['InvoiceDate']= pd.to_datetime(retail['InvoiceDate'])

# %%
retail['date']= retail.InvoiceDate.dt.strftime('%Y-%m-%d')

# %%
retail['date']=pd.to_datetime(retail['date'])

# %%
max_data = max(retail.date)
max_data
# Out:
# Timestamp('2011-12-09 00:00:00')

# %%
last_four= retail[retail.date > '2011-08-01']
last_four.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country', 'date'],
#       dtype='object')

# %%
last_four['revenue']= last_four['Quantity']* last_four['Price']
# Out:
# <ipython-input-14-6ad8b059c5b7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_four['revenue']= last_four['Quantity']* last_four['Price']

# %%
a=last_four.groupby(['date','Description']).agg(total_daily= ('Quantity',np.sum),
                                             total_revenue= ('revenue',np.sum)).reset_index()

# %%
grouped = a.groupby('Description').agg(average= ('total_daily',np.mean),
                                       sd= ('total_daily','std'),
                                       total_sales= ('total_daily',np.sum),
                                       total_revenue=('total_revenue',np.sum)).reset_index()
grouped
# Out:
#                            Description    average         sd  total_sales  \
# 0        4 PURPLE FLOCK DINNER CANDLES   5.300000   6.105218          106
# 1        50'S CHRISTMAS GIFT BAG LARGE  31.383333  55.507242         1883
# 2                    DOLLY GIRL BEAKER  29.743590  73.454012         2320
# 3          I LOVE LONDON MINI BACKPACK   8.159091  11.966898          359
# 4          I LOVE LONDON MINI RUCKSACK   1.000000        NaN            1
# ...                                ...        ...        ...          ...
# 3216   ZINC T-LIGHT HOLDER STARS SMALL  30.487500  37.806635         2439
# 3217    ZINC TOP  2 DOOR WOODEN SHELF    1.000000        NaN            1
# 3218  ZINC WILLIE WINKIE  CANDLE STICK  24.594203  30.790716         1697
# 3219       ZINC WIRE KITCHEN ORGANISER   2.714286   2.984085           19
# 3220  ZINC WIRE SWEETHEART LETTER TRAY   3.300000   3.860052           33
#
#       total_revenue
# 0            184.06
# 1           2269.75
# ...

# %% [markdown]
# ### Segmentation of data for service level (Segmentación de datos por nivel de servicio):

# %%
for_abc = inv.productmix(grouped['Description'], grouped['total_sales'], grouped['total_revenue'])
for_abc
# Out:
#                                      skus  sales   revenue  sales_mix  \
# 2162                   RABBIT NIGHT LIGHT  24112  45484.50   0.010261
# 2263             REGENCY CAKESTAND 3 TIER   3482  40660.05   0.001482
# 1432              JUMBO BAG RED RETROSPOT  20013  37823.09   0.008516
# 1902      PAPER CHAIN KIT 50'S CHRISTMAS   12680  34788.68   0.005396
# 3074   WHITE HANGING HEART T-LIGHT HOLDER  11634  32375.26   0.004951
# ...                                   ...    ...       ...        ...
# 1148                   GLASS  BEURRE DISH     -8    -29.92  -0.000003
# 2953         VINTAGE BLUE KITCHEN CABINET      0    -75.00   0.000000
# 3092  WHITE TALL PORCELAIN T-LIGHT HOLDER   -208   -386.40  -0.000089
# 881                              Discount    -37  -1899.52  -0.000016
# 725                       CRUK Commission    -16  -7933.43  -0.000007
#
#       comulative_sales  revenue_mix  comulative_revenue sales_category  \
# ...

# %%
for_abc.product_mix.value_counts()
# Out:
# C_C    1456
# A_A     501
# B_B     314
# B_C     238
# C_B     235
# A_B     226
# B_A     174
# A_C      42
# C_A      35
# Name: product_mix, dtype: int64

# %% [markdown]
# ### Reorder point for all SKUs (Punto de reorden para todos los SKUs):

# %%
lead_time = 12
sd_leadtime = 2

# %%
mapping = {'A_A':0.95,"A_C": 0.95,"C_A":0.8,"A_B":0.95,'B_A':0.7,"B_C":0.75,"C_C":0.7,"B_B":0.7,"C_B": 0.8}

# %%
for_abc['service_level']=for_abc.product_mix.map(mapping)

# %%
### reorder point:

pd.DataFrame(inv.reorderpoint(80, 10, 12, 0.75),index=[0])
# Out:
#    demandleadtime    sigmadl  safteyfactor  reorder_point
# 0             960  34.641016       0.67449      983.36501

# %%
abcd = for_abc[['skus','service_level']]
abcd
# Out:
#                                      skus  service_level
# 2162                   RABBIT NIGHT LIGHT           0.95
# 2263             REGENCY CAKESTAND 3 TIER           0.95
# 1432              JUMBO BAG RED RETROSPOT           0.95
# 1902      PAPER CHAIN KIT 50'S CHRISTMAS            0.95
# 3074   WHITE HANGING HEART T-LIGHT HOLDER           0.95
# ...                                   ...            ...
# 1148                   GLASS  BEURRE DISH           0.70
# 2953         VINTAGE BLUE KITCHEN CABINET           0.70
# 3092  WHITE TALL PORCELAIN T-LIGHT HOLDER           0.70
# 881                              Discount           0.70
# 725                       CRUK Commission           0.70
#
# [3221 rows x 2 columns]

# %%
for_reorder = pd.merge(grouped, abcd,how='left',left_on ='Description',right_on ='skus')
for_reorder
# Out:
#                            Description    average         sd  total_sales  \
# 0        4 PURPLE FLOCK DINNER CANDLES   5.300000   6.105218          106
# 1        50'S CHRISTMAS GIFT BAG LARGE  31.383333  55.507242         1883
# 2                    DOLLY GIRL BEAKER  29.743590  73.454012         2320
# 3          I LOVE LONDON MINI BACKPACK   8.159091  11.966898          359
# 4          I LOVE LONDON MINI RUCKSACK   1.000000        NaN            1
# ...                                ...        ...        ...          ...
# 3216   ZINC T-LIGHT HOLDER STARS SMALL  30.487500  37.806635         2439
# 3217    ZINC TOP  2 DOOR WOODEN SHELF    1.000000        NaN            1
# 3218  ZINC WILLIE WINKIE  CANDLE STICK  24.594203  30.790716         1697
# 3219       ZINC WIRE KITCHEN ORGANISER   2.714286   2.984085           19
# 3220  ZINC WIRE SWEETHEART LETTER TRAY   3.300000   3.860052           33
#
#       total_revenue                              skus  service_level
# ...

# %%
for_reorder.columns
# Out:
# Index(['Description', 'average', 'sd', 'total_sales', 'total_revenue', 'skus',
#        'service_level'],
#       dtype='object')

# %%
empty_data = pd.DataFrame()

# %%
for i in range(for_reorder.shape[0]):
    ordering_point= inv.reorderpoint(for_reorder.loc[i,'average'],
                                     for_reorder.loc[i,'sd'],
                                     12, for_reorder.loc[i,'service_level'])
    as_data= pd.DataFrame(ordering_point,index=[0])
    as_data['Description']= for_reorder.loc[i,'Description']
    empty_data=pd.concat([empty_data,as_data],axis=0)

# %%
empty_data
# Out:
#     demandleadtime     sigmadl  safteyfactor  reorder_point  \
# 0        63.600000   21.149095      0.524401      74.690596
# 0       376.600000  192.282728      1.644854     692.876942
# 0       356.923077  254.452161      1.644854     775.459636
# 0        97.909091   41.454552      0.524401     119.647879
# 0        12.000000         NaN      0.524401            NaN
# ..             ...         ...           ...            ...
# 0       365.850000  130.966024      1.644854     581.269939
# 0        12.000000         NaN      0.524401            NaN
# 0       295.130435  106.662170      1.644854     470.574091
# 0        32.571429   10.337173      0.524401      37.992247
# 0        39.600000   13.371612      0.524401      46.612080
#
#                          Description
# 0      4 PURPLE FLOCK DINNER CANDLES
# 0      50'S CHRISTMAS GIFT BAG LARGE
# 0                  DOLLY GIRL BEAKER
# 0        I LOVE LONDON MINI BACKPACK
# 0        I LOVE LONDON MINI RUCKSACK
# ...

# %% [markdown]
# ### Reorder point Conclusion (Punto de reorden Conclusión):

# %%
## uniéndose a todos
all_data = pd.merge(for_reorder, empty_data,how='left')

# %%
all_data.columns
# Out:
# Index(['Description', 'average', 'sd', 'total_sales', 'total_revenue', 'skus',
#        'service_level', 'demandleadtime', 'sigmadl', 'safteyfactor',
#        'reorder_point'],
#       dtype='object')

# %%
all_data['saftey_stock'] = all_data['reorder_point'] - all_data['demandleadtime']

# %%
all_data[all_data.saftey_stock == max(all_data.saftey_stock)]
# Out:
#                         Description  average           sd  total_sales  \
# 222  ASSTD DESIGN 3D PAPER STICKERS   1590.5  4424.387803        12724
#
#      total_revenue                            skus  service_level  \
# 222          95.68  ASSTD DESIGN 3D PAPER STICKERS           0.95
#
#      demandleadtime       sigmadl  safteyfactor  reorder_point  saftey_stock
# 222         19086.0  15326.528933      1.644854   44295.896704  25209.896704

# %%
all_data = all_data[all_data.saftey_stock != max(all_data.saftey_stock)]
all_data
# Out:
#                            Description    average         sd  total_sales  \
# 0        4 PURPLE FLOCK DINNER CANDLES   5.300000   6.105218          106
# 1        50'S CHRISTMAS GIFT BAG LARGE  31.383333  55.507242         1883
# 2                    DOLLY GIRL BEAKER  29.743590  73.454012         2320
# 3          I LOVE LONDON MINI BACKPACK   8.159091  11.966898          359
# 4          I LOVE LONDON MINI RUCKSACK   1.000000        NaN            1
# ...                                ...        ...        ...          ...
# 3216   ZINC T-LIGHT HOLDER STARS SMALL  30.487500  37.806635         2439
# 3217    ZINC TOP  2 DOOR WOODEN SHELF    1.000000        NaN            1
# 3218  ZINC WILLIE WINKIE  CANDLE STICK  24.594203  30.790716         1697
# 3219       ZINC WIRE KITCHEN ORGANISER   2.714286   2.984085           19
# 3220  ZINC WIRE SWEETHEART LETTER TRAY   3.300000   3.860052           33
#
#       total_revenue                              skus  service_level  \
# ...

# %%
sns.scatterplot(x ='sd',y ='saftey_stock',hue ='service_level',data = all_data)
# Out:
# <AxesSubplot:xlabel='sd', ylabel='saftey_stock'>

# %% [markdown]
# ### Lead Time Variability (Variabilidad del tiempo de entrega):

# %%
Image('LT.png')

# %% [markdown]
# - Tiempo de tránsito aduanero.
# - Fabricación.
# - El tiempo de entrega.
# - Las condiciones climáticas.
# - Consolidación de Envíos.
# - Retraso en los acuerdos contractuales.
# - SS sin variabilidad del tiempo de entrega.
# - SS con variabilidad del tiempo de entrega.

# %%
## con variabilidad del tiempo de entrega:
empty_data_ltv = pd.DataFrame()

# %%
for i in range(for_reorder.shape[0]):
    ordering_point= inv.reorderpoint_leadtime_variability(int(for_reorder.loc[i,'average']),
                                     for_reorder.loc[i,'sd'],
                                     12,2, for_reorder.loc[i,'service_level'])
    as_data= pd.DataFrame(ordering_point,index=[0])
    as_data['Description']= for_reorder.loc[i,'Description']
    empty_data_ltv=pd.concat([empty_data_ltv,as_data],axis=0)

# %%
empty_data_ltv
# Out:
#     demandleadtime     sigmadl  safteyfactor  reorder_point  \
# 0               60   22.254982      0.524401      71.670524
# 0              372  197.212189      1.644854     696.385184
# 0              348  257.732229      1.644854     771.931792
# 0               96   42.993952      0.524401     118.546051
# 0               12         NaN      0.524401            NaN
# ..             ...         ...           ...            ...
# 0              360  137.673888      1.644854     586.453394
# 0               12         NaN      0.524401            NaN
# 0              288  111.941138      1.644854     472.126787
# 0               24   10.810048      0.524401      29.668795
# 0               36   13.957077      0.524401      43.319098
#
#                          Description
# 0      4 PURPLE FLOCK DINNER CANDLES
# 0      50'S CHRISTMAS GIFT BAG LARGE
# 0                  DOLLY GIRL BEAKER
# 0        I LOVE LONDON MINI BACKPACK
# 0        I LOVE LONDON MINI RUCKSACK
# ...

# %%
## uniéndose a todos
all_data_ltv = pd.merge(for_reorder, empty_data_ltv,how='left')
all_data_ltv

# %%
all_data.columns
# Out:
# Index(['Description', 'average', 'sd', 'total_sales', 'total_revenue', 'skus',
#        'service_level', 'demandleadtime', 'sigmadl', 'safteyfactor',
#        'reorder_point', 'saftey_stock'],
#       dtype='object')

# %%
all_data['saftey_stock'] = all_data['reorder_point']-all_data['demandleadtime']

# %%
all_data[all_data.saftey_stock == max(all_data.saftey_stock)]
# Out:
#                       Description     average          sd  total_sales  \
# 2682  SMALL CHINESE STYLE SCISSOR  297.478261  749.591093         6842
#
#       total_revenue                         skus  service_level  \
# 2682        2223.64  SMALL CHINESE STYLE SCISSOR           0.95
#
#       demandleadtime      sigmadl  safteyfactor  reorder_point  saftey_stock
# 2682      3569.73913  2596.659715      1.644854    7840.864281    4271.12515

# %%
all_data = all_data[all_data.saftey_stock != max(all_data.saftey_stock)]
all_data
# Out:
#                            Description    average         sd  total_sales  \
# 0        4 PURPLE FLOCK DINNER CANDLES   5.300000   6.105218          106
# 1        50'S CHRISTMAS GIFT BAG LARGE  31.383333  55.507242         1883
# 2                    DOLLY GIRL BEAKER  29.743590  73.454012         2320
# 3          I LOVE LONDON MINI BACKPACK   8.159091  11.966898          359
# 4          I LOVE LONDON MINI RUCKSACK   1.000000        NaN            1
# ...                                ...        ...        ...          ...
# 3216   ZINC T-LIGHT HOLDER STARS SMALL  30.487500  37.806635         2439
# 3217    ZINC TOP  2 DOOR WOODEN SHELF    1.000000        NaN            1
# 3218  ZINC WILLIE WINKIE  CANDLE STICK  24.594203  30.790716         1697
# 3219       ZINC WIRE KITCHEN ORGANISER   2.714286   2.984085           19
# 3220  ZINC WIRE SWEETHEART LETTER TRAY   3.300000   3.860052           33
#
#       total_revenue                              skus  service_level  \
# ...

# %%
sns.scatterplot(x ='sd',y ='saftey_stock',hue ='service_level',data = all_data)
# Out:
# <AxesSubplot:xlabel='sd', ylabel='saftey_stock'>

# %% [markdown]
# ### Summary (Resumen):

# %% [markdown]
# En esta sección, hemos llegado a saber cómo calcular el stock de seguridad utilizando los parámetros que tenemos para nuestros productos. Entonces, lo primero que debemos hacer es obtener la demanda promedio o la demanda diaria promedio, y luego convertirla al período de la primera hora.
#
# Entonces, por ejemplo, si su demanda diaria, esta es de 10 por día y su tiempo de entrega es de una semana, entonces multiplique por siete, obtendrá el tiempo de entrega de demanda que tiene. La oferta simplemente es igual a la demanda promedio multiplicada por el tiempo de entrega. Entonces, esta es la demanda diaria promedio y luego tiene la desviación estándar sigma, por lo que Sigma diario, sabemos cómo obtener Sigma usando este TGV en Excel y como el y si desea el trato Sigma. Será sigma multiplicado por la raíz cuadrada del tiempo de entrega.
#
# Esto es si usted es un sigma de aumento, pero si tiene el sigma durante un año, por ejemplo, y quiere un día, entonces será sigma multiplicado por 1/365 para obtener por día, entonces esto es cómo calcule Sigma y finalmente su stock de seguridad será esta parte multiplicada por Sigma.
#
# Multiplicado por un factor clave, este factor clave es el nivel de servicio que define. Correcto, tal vez el 70, el 80% o el 95%, y cómo se define el nivel de servicio usando el B.S., y eso es ahora también hay una variabilidad de tiempo que podemos tener. Y puede ver que cuando no hay disponibilidad de tiempo, el stock de seguridad es menor que el stock de seguridad. Por lo tanto, esto es sin la variabilidad del tiempo de entrega, y esto es con la variabilidad del tiempo de entrega. Así que ahora tenemos y dijimos que el punto de reorden es, ¿son los hombres iguales en esta parte?
#
# Además, Sigma multiplicado por el factor clave. Esta parte está teniendo suficiente hasta que mi proveedor envíe los artículos por mí, porque si no tengo esta parte, eso significa que me quedaré la noche sin existencias. Y mis clientes me preguntan dónde están los productos.
#
# Por lo tanto, tenemos que contar para que este vuelo tenga en cuenta la variabilidad de la demanda de los clientes durante el fin de semana, durante los días de semana. No estoy seguro de cuánto venderé mañana. Nadie sabe.
#
# Entonces esta parte es para contar esta variabilidad a medida que disminuimos el nivel de servicio, a medida que esta parte disminuye, a medida que aumentamos el nivel de servicio, a medida que esta parte aumenta, y seguirán la misma regla en muchas de nuestras políticas que haremos en la siguiente sección.
#
# Esta regla se mantendrá y ahora tiene el paquete de inventarios para ayudarlo a hacer estos cálculos de una sola vez sin depender de Excel o sin hacer lo mismo todo el tiempo. Simplemente haces la manipulación y luego tu bucle *for* las funciones de inventarios y luego obtienes los cálculos, como hemos visto en la conferencia y también como hemos visto en la tarea, esta sección es muy importante.
#
# Revíselo y mire los videos nuevamente, porque realmente debe dominar la habilidad de definir el punto de reorden y definir su inventario de seguridad.
